# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def procesar_pagina(soup):

    data = []

    titulos=[]
    autores=[]
    precios_sin_descuento=[]
    precios_con_descuento=[]

    titulo_libros = soup.find_all('dd', class_='title')
    
    for item in titulo_libros:
        titulo=item.a.text.strip()
        titulos.append(titulo)

    autor_libros = soup.find_all('dd', class_='creator')

    for item in autor_libros:
        autor=item.text.strip()
        autores.append(autor)

    strike=soup.select('p.precio strike')

    for item in strike:
        precio=item.text.strip()
        precios_sin_descuento.append(precio)

    strong=soup.select('p.precio strong')

    for item in strong:
        precio=item.text.strip()
        precios_con_descuento.append(precio)

    min_length = min(len(titulos), len(autores), len(precios_sin_descuento), len(precios_con_descuento))

    for i in range (min_length):
        data.append(
            {
                'Titulo':titulos[i],
                'Autores':autores[i],
                'Precio inicial':precios_sin_descuento[i],
                'Precio final':precios_con_descuento[i]
            }
        )

    df=pd.DataFrame(data)

    df.to_csv("/Users/carlo/OneDrive/Escritorio/Curso-python/Actividad_Pagina_WebScraping/librosDescuentoGonvil.csv", index=False, mode='a')

    print(df)

# %%
def obtener_contenido(url):
    response = requests.get(url)
    return response.content

# %%
def analizar_contenido(html):
    return BeautifulSoup(html, 'html.parser')

# %%
def manejar_paginacion(url_base, num_paginas):
    for i in range(1, num_paginas+1):
        url=url_base + str(i) + '&cuantos=20&orden=prioridad%2C+fecha_edicion+desc&titulo=C%E1lculo'
        contenido_pagina=obtener_contenido(url)
        soup= analizar_contenido(contenido_pagina)
        procesar_pagina(soup)

# %%
url_base='https://www.gonvill.com.mx/busqueda/listaLibros.php?pagSel='

num_paginas=10

manejar_paginacion(url_base,num_paginas)
# Out:
#                                                Titulo  \
# 0   CALCULO DIFERENCIAL      (DGB/S.INTEGRAL COMPE...
# 1                                 CÁLCULO DIFERENCIAL
# 2   CÁLCULO DIFERENCIAL 2ED. -COMPETENCIA+APRENDIZ...
# 3                                    CÁLCULO INTEGRAL
# 4                                 CÁLCULO DIFERENCIAL
# 5   CÁLCULO DIFERENCIAL                  SC -COMPE...
# 6                 CÁLCULO DIFERENCIAL E INTEGRAL 2ED.
# 7   CÁLCULO INTEGRAL BACH. 2ED. -COMPETENCIAS+APRE...
# 8                                    CÁLCULO INTEGRAL
# 9   CALCULO APLICADO TOMO 3 -COMPETENCIAS MATEMATI...
# 10                MATEMÁTICAS I -CÁLCULO DIFERENCIAL-
# 11      MATEMÁTICAS III -CÁLCULO DE VARIAS VARIABLES-
# 12               CÁLCULO DE LÍNEAS Y REDES ELÉCTRICAS
# 13  ESTRUCTURAS DE HORMIGÓN ARMADO -PREDIMENSIONAM...
# 14  COLECCIÓN LIPPINCOTT ENFERMERÍA 5ED. -CÁLCULO ...
#
#                                               Autores Precio inicial  \
# 0                               ORTIZ, FRANCISCO    .        $199.00
# 1                        ORTIZ CAMPOS, FRANCISCO JOSÉ        $275.00
# 2             JIMÉNEZ            /            ESTRADA        $315.00
# 3                        ORTIZ CAMPOS, FRANCISCO JOSÉ        $275.00
# 4   RAMOS            /            GÓMEZ           ...        $528.00
# 5            CALLEJAS            /            JIMÉNEZ        $210.00
# 6               DE OTEYZA            /            LAM        $429.00
# 7             JIMÉNEZ            /            ESTRADA        $315.00
# 8                                         RAMOS, JOSÉ        $228.00
# 9                                             SALINAS        $479.00
# 10             LARSON            /            EDWARDS        $280.00
# 11             LARSON            /            EDWARDS        $280.00
# 12                                 MUJAR ROSAS, RAMÓN        $398.00
# 13                GÓMEZ            /            GÓMEZ        $268.00
# 14                                   HARVEY, MARGARET        $534.00
#
#    Precio final
# 0       $179.10
# 1       $247.50
# 2       $270.90
# 3       $247.50
# 4       $475.20
# 5       $180.60
# 6       $368.94
# 7       $270.90
# 8       $205.20
# 9       $431.10
# 10      $252.00
# 11      $252.00
# 12      $358.20
# 13      $241.20
# 14      $427.20
#                                                Titulo  \
# 0   CÁLCULO MENTAL 6 PRIM. 2ED. -Y ESTIMACIÓN DE R...
# 1                                 CÁLCULO DIFERENCIAL
# 2              CÁLCULO DIFERENCIAL -BACH.TECNOLÓGICO-
# 3                            CÁLCULO DIFERENCIAL 4ED.
# 4       PRECÁLCULO 7ED. -MATEMÁTICAS PARA EL CÁLCULO-
# 5   CALCULO INTEGRAL PARA CURSOS CON ENFOQUE POR C...
# 6                                    CALCULO INTEGRAL
# 7                               CALCULO INTEGRAL 2ED.
# 8                 CÁLCULO DIFERENCIAL 4ED. (C/ACCESO)
# 9   CÁLCULO UNA VARIABLE 13ED. (COD.ACCESO/MYMATHLAB)
# 10            MATEMÁTICAS 5 (CÁLCULO DIFERENCIAL)  IE
# 11  CÁLCULO INTEGRAL                     SC -COMPE...
# 12  CALCULO DIFERENCIAL              (BACH. POR CO...
# 13                                CALCULO VISUAL C/CD
# 14  APRENDO JUGANDO -EJERCICIOS DE CÁLCULO (6-7 AÑ...
# 15  ELEMENTOS FUNDAMENTALES EN EL CÁLCULO DE DIETA...
# 16                                 CALCULO 2ED. VOL.1
#
#                                               Autores Precio inicial  \
# 0   ZÚÑIGA            /            ZÚÑIGA         ...        $275.00
# 1                    SALAZAR GUERRERO, LUDWING JAVIER        $197.00
# 2             ESTRADA            /            JIMÉNEZ        $272.00
# 3                                 FUENLABRADA, SAMUEL        $681.00
# 4                                      STEWART, JAMES        $410.00
# 5                                  MORALES, FELICITAS        $170.00
# 6                                     GARZA, BENJAMIN        $186.00
# 7                                     GARZA, BENJAMIN        $770.00
# 8                                             CONAMAT        $170.00
# 9                                              THOMAS        $210.00
# 10           CALLEJAS            /            JIMÉNEZ        $349.00
# 11                  FOX            /            ORTIZ        $110.00
# 12               MAYA            /            AGUIRRE        $360.00
# 13                                     CUEVAS, CARLOS        $314.00
# 14                                             COMBEL        $272.00
# 15                                  ASCENCIO, CLAUDIA        $165.00
# 16                                   SMITH, ROBERT T.        $145.00
#
#    Precio final
# 0       $247.50
# 1       $169.42
# 2       $244.80
# 3       $612.90
# 4       $352.60
# 5       $146.20
# 6       $159.96
# 7       $662.20
# 8       $146.20
# 9       $180.60
# 10      $314.10
# 11       $88.00
# 12      $324.00
# 13      $282.60
# 14      $244.80
# 15      $148.50
# 16      $130.50
#                                                Titulo  \
# 0   DISEÑO Y CÁLCULO DE ESTRUCTURAS DE CONCRETO RE...
# 1           CÁLCULO MENTAL ES UN JUEGO (7-9 AÑOS), EL
# 2                         CÁLCULO DIFERENCIAL (DGETI)
# 3      DESARROLLE SU CÁLCULO EN AJEDREZ -MEDIO JUEGO-
# 4          DESARROLLE SU CÁLCULO EN AJEDREZ -FINALES-
# 5                 CÁLCULO DIFERENCIAL       (CONALEP)
# 6   CÁLCULO INTEGRAL BACH. C/CD (COMPETENCIAS/S.SLIM)
# 7                  CÁLCULO I -CONCEPTOS Y EJERCICIOS-
# 8           CALCULO DIFERENCIAL (MEDIA SUPERIOR/BPEM)
# 9   CALCULO DIFERENCIAL -FUNCIONES/LIMITES/DERIVAD...
# 10              CALCULO DIFERENCIAL PARA BACHILLERATO
# 11                            FUNDAMENTOS DEL CALCULO
# 12                        CALCULO PROBLEMAS RESUELTOS
# 13  VIVE EL CALCULO DIFERENCIAL -BACH./PIADA/COMPE...
# 14                      ESENCIALES DE CALCULO (BACH.)
# 15  CALCULO VOL. II (INTEGRALES, SERIES Y APLICACI...
# 16                  MATEMATICAS V CALCULO DIFERENCIAL
#
#                                     Autores Precio inicial Precio final
# 0                      PÉREZ ALAMÁ, VICENTE        $799.00      $719.10
# 1                               ROUGIER, R.        $130.00      $111.80
# 2     GARCÍA            /            GUERRA        $230.00      $218.50
# 3                           EDOUARD, ROMAIN        $390.00      $292.50
# 4                           EDOUARD, ROMAIN        $390.00      $292.50
# 5                               ASTEY, LUIS        $260.00      $234.00
# 6                         FERRAL, E. ARTURO        $170.00      $161.50
# 7                            IDEA PENTÁGONO        $180.00      $171.00
# 8                         ALVARADO, RODOLFO        $172.00      $163.40
# 9                     DIAZ CERON, FRANCISCO        $410.00      $352.60
# 10                     GARCIA JUAREZ, MARCO        $387.00      $332.82
# 11  FLORES            /            VALENCIA        $200.00      $180.00
# 12                                CARBONELL        $220.00      $198.00
# 13  ROMERO            /            BARCENAS        $289.00      $260.10
# 14                              LAPIZ-TINTA        $150.00      $135.00
# 15                           REYES, ARACELI        $210.00      $157.50
# 16                         IBAÑEZ, PATRICIA        $531.00      $456.66
#                                Titulo         Autores Precio inicial  \
# 0  CÁLCULO 1 -PROBLEMAS Y SOLUCIONES-  STEWART, JAMES        $195.00
# 1  CÁLCULO 2 -PROBLEMAS Y SOLUCIONES-  STEWART, JAMES        $195.00
#
#   Precio final
# 0      $175.50
# 1      $175.50
#                                               Titulo  \
# 0             FISICA II 3ED. TEXTO BASADO EN CALCULO
# 1                               ELEMENTOS DE CALCULO
# 2                CÁLCULO INTEGRAL -BACH.TECNOLÓGICO-
# 3  MATEMÁTICA AVANZADA -CÁLCULO DIFERENCIAL- (BAC...
# 4  CÁLCULO DE UNA VARIABLE (BUNDLE INCLUYE WA LAB...
#
#                                    Autores Precio inicial Precio final
# 0                       SERWAY, RAYMOND A.        $335.00      $301.50
# 1                                  CORDOBA        $217.00      $186.62
# 2  ESTRADA            /            JIMÉNEZ        $692.00      $622.80
# 3    ZÁRATE            /            GARCÍA        $425.00      $382.50
# 4                           STEWART, JAMES        $340.00      $306.00
# Empty DataFrame
# Columns: []
# Index: []
#                                 Titulo               Autores Precio inicial  \
# 0       CÁLCULO DIFERENCIAL E INTEGRAL  SILVANUS P. THOMPSON        $730.00
# 1     MATEMÁTICAS VI. CÁLCULO INTEGRAL  JUAN ANTONIO CUéLLAR        $190.00
# 2   MATEMÁTICAS V. CÁLCULO DIFERENCIAL  JUAN ANTONIO CUéLLAR        $180.00
# 3                  CÁLCULO DIFERENCIAL               CONAMAT        $429.00
# 4                     CÁLCULO INTEGRAL               CONAMAT        $278.00
# 5                              CÁLCULO       ROBERT A. ADAMS        $265.00
# 6       CÁLCULO DIFERENCIAL E INTEGRAL               CONAMAT        $380.00
# 7  CÁLCULO CON TRASCENDENTES TEMPRANAS      HENRY C. EDWARDS        $275.00
# 8                 CÁLCULO UNA VARIABLE  GEORGE B.THOMAS, JR.      $1,007.00
#
#   Precio final
# 0      $627.80
# 1      $171.00
# 2      $162.00
# 3      $386.10
# 4      $250.20
# 5      $238.50
# 6      $342.00
# 7      $247.50
# 8      $805.60
#                                               Titulo  \
# 0  CÁLCULO DIFERENCIAL (DGB/NVO.MODELO EDUCATIVO/...
# 1  CÁLCULO INTEGRAL -PENSAMIENTO Y LENGUAJE VARIA...
# 2  PLATAFORMA CONNECT 18MESES CALCULO 5ED. -TRASC...
# 3  PLATAFORMA CONNECT 12MESES CALCULO UNA VARIABL...
# 4  PLATAFORMA CONNECT 12MESES CALCULO DE VARIAS V...
# 5                            CÁLCULO DE UNA VARIABLE
# 6                        CÁLCULO DE VARIAS VARIABLES
#
#                                              Autores Precio inicial  \
# 0                GARCÍA            /            MAYA        $650.00
# 1  SÁNCHEZ            /            GARCÍA        ...        $455.00
# 2                                   MCGRAWHILL-SMITH        $469.00
# 3                                   MCGRAWHILL-SMITH        $419.00
# 4                                   MCGRAWHILL-SMITH        $187.00
# 5                                     DENNIS G. ZILL        $555.00
# 6                                     DENNIS G. ZILL        $655.00
#
#   Precio final
# 0      $559.00
# 1      $409.50
# 2      $422.10
# 3      $377.10
# 4      $168.30
# 5      $499.50
# 6      $589.50
#                                               Titulo  \
# 0                      CALCULO (EL VERBO DEL COSMOS)
# 1  METODO SIMPLIFICADO DE MULTIPLICACION Y CALCUL...
# 2          MATEMATICAS 3 CALCULO DE VARIAS VARIABLES
# 3                            CALCULO DE ANTENAS 4ED.
# 4  CALCULO DIFERENCIAL EN VARIAS VARIABLES C/660 ...
#
#                                              Autores Precio inicial  \
# 0                                      FRANCO, JORGE        $567.00
# 1                                      HANDLEY, BILL        $640.00
# 2                                             LARSON        $488.00
# 3                                    GARCIA, ARMANDO        $430.00
# 4  BESADA            /            GARCIA         ...        $430.00
#
#   Precio final
# 0      $510.30
# 1      $550.40
# 2      $419.68
# 3      $369.80
# 4      $369.80
#                                               Titulo  \
# 0                           CALCULO DIFERENCIAL 2ED.
# 1                              CÁLCULO INTEGRAL 4ED.
# 2  ESTIMULACIÓN DE LAS FUNC.COGN. NIVEL 2 CUAD.2 ...
# 3  NUTRICIÓN PRINCIPIOS DE DIETO-CÁLCULO -PASO A ...
# 4             CÁLCULO DE VARACIONES Y CONTROL OPTIMO
# 5  CALCULO DIFERENCIAL                           ...
# 6  CALCULO DIFERENCIAL              (BACH. POR CO...
# 7  CALCULO INTEGRAL                 (BACH. POR CO...
# 8              APLICACIONES DE CALCULO PARA LA TI-89
# 9               CÁLCULO TRASCENDENTES TEMPRANAS 2ED.
#
#                                  Autores Precio inicial Precio final
# 0                        GARZA, BENJAMIN        $175.00      $150.50
# 1                                CONAMAT        $280.00      $252.00
# 2                           LEÓN, CARMEN        $280.00      $240.80
# 3                       GUTIÉRREZ, RAMÓN         $75.00       $67.50
# 4                     VALDOVINOS, VÍCTOR        $180.00      $162.00
# 5                             JUNEZ VEGA        $521.00      $468.90
# 6  VALENCIA            /            BACA        $765.00      $688.50
# 7                    VALENCIA, FRANCISCO        $459.00      $413.10
# 8                            BARTON, RAY        $455.00      $409.50
# 9                                  ANTON        $359.00      $323.10
